# %%
import pandas as pd
import yfinance as yf
import datetime
from pandas_datareader.data import DataReader

# %%
tickers = ['AMZN', 'AAPL', 'MSFT', 'GOOG', 'PYPL', 'ADBE', 'NVDA', 'TSLA']
df = DataReader(tickers, 'yahoo', start = '2015-8-23')['Adj Close']
df
# Out:
# Symbols           AMZN        AAPL        MSFT       GOOG       PYPL  \
# Date
# 2015-08-24   23.168501   23.500523   37.222427  29.480499  33.750000
# 2015-08-25   23.318501   23.641819   36.141838  29.103001  32.700001
# 2015-08-26   25.038500   24.997793   38.142273  31.431000  33.169998
# 2015-08-27   25.918501   25.733894   39.205013  31.880501  34.619999
# 2015-08-28   25.900499   25.818214   39.231808  31.518999  35.040001
# ...                ...         ...         ...        ...        ...
# 2022-11-09   86.139999  134.869995  224.509995  87.400002  78.680000
# 2022-11-10   96.629997  146.869995  242.979996  94.169998  86.800003
# 2022-11-11  100.790001  149.699997  247.110001  96.730003  91.029999
# 2022-11-14   98.489998  148.279999  241.550003  96.029999  89.510002
# 2022-11-15   98.940002  150.039993  241.970001  98.720001  89.860001
#
# Symbols           ADBE        NVDA        TSLA
# Date
# 2015-08-24   74.269997    5.038919   14.591333
# ...

# %%
# Out:
# ...
#      -------------------------------------- 109.5/109.5 kB 2.1 MB/s eta 0:00:00
# ...
