# %%
import backtrader as bt
import datetime
import yfinance as yf
# %matplotlib inline

# %%
cerebro = bt.Cerebro()

# %%
df = yf.download('AAPL', start='2010-1-1')
# Out:
# [*********************100%***********************]  1 of 1 completed

# %%
feed = bt.feeds.PandasData(dataname=df)

# %%
cerebro.adddata(feed)

# %%
cerebro.run()

# %%
cerebro.plot()
# Out:
# <img src="data:image/png;base64,..." width="432.2222336722012">
# [[<Figure size 432x288 with 4 Axes>]]

# %%
# Out:
# ...
#   Cloning https://github.com/mementum/backtrader.git (to revision 0fa63ef4a35dc53cc7320813f8b15480c8f85517) to c:\users\personal\appdata\local\temp\pip-install-1ck3yp5l\backtrader_8c0c5d8b5a0040bcb0c0636d545518dc
#   Resolved https://github.com/mementum/backtrader.git to commit 0fa63ef4a35dc53cc7320813f8b15480c8f85517
#   Running command git clone -q https://github.com/mementum/backtrader.git 'C:\Users\Personal\AppData\Local\Temp\pip-install-1ck3yp5l\backtrader_8c0c5d8b5a0040bcb0c0636d545518dc'
#   Running command git rev-parse -q --verify 'sha^0fa63ef4a35dc53cc7320813f8b15480c8f85517'
#   Running command git fetch -q https://github.com/mementum/backtrader.git 0fa63ef4a35dc53cc7320813f8b15480c8f85517
#   Running command git checkout -q 0fa63ef4a35dc53cc7320813f8b15480c8f85517
# ...
#   Created wheel for backtrader: filename=backtrader-1.9.76.123-py3-none-any.whl size=422031 sha256=b89145ba09ee6bdd1cca419a03ae4f8de31a60813a8a10ae890193cf4631331e
# ...
