# %%
import requests
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import json
import pprint
from datetime import datetime, timedelta
pd.set_option('display.max_rows', 10)
pd.set_option('display.max_columns', 10)
pd.set_option('display.width', 2000)

# %%
import requests

url = "https://yahoo-finance15.p.rapidapi.com/api/yahoo/qu/quote/AAPL"

headers = {
	"X-RapidAPI-Key": "f7d325e8a3msh27bd0610a1dc4c8p11c6b4jsn5d3a3e2084fa",
	"X-RapidAPI-Host": "yahoo-finance15.p.rapidapi.com"
}

response = requests.request("GET", url, headers=headers)
data = json.loads(response.text)

print(response.status_code)

pprint.pprint (data)
# Out:
# 200
# [{'ask': 150.81,
#   'askSize': 8,
#   'averageDailyVolume10Day': 90941460,
#   'averageDailyVolume3Month': 89858307,
#   'bid': 150.86,
#   'bidSize': 13,
#   'bookValue': 3.178,
#   'currency': 'USD',
#   'dividendDate': {'date': '2022-11-10 00:00:00.000000',
#                    'timezone': '+00:00',
#                    'timezone_type': 1},
#   'earningsTimestamp': {'date': '2022-10-27 21:00:00.000000',
#                         'timezone': '+00:00',
#                         'timezone_type': 1},
#   'earningsTimestampEnd': {'date': '2023-01-30 12:00:00.000000',
#                            'timezone': '+00:00',
#                            'timezone_type': 1},
#   'earningsTimestampStart': {'date': '2023-01-25 10:59:00.000000',
#                              'timezone': '+00:00',
#                              'timezone_type': 1},
#   'epsForward': 6.82,
#   'epsTrailingTwelveMonths': 6.11,
#   'exchange': 'NMS',
#   'exchangeDataDelayedBy': 0,
#   'exchangeTimezoneName': 'America/New_York',
#   'exchangeTimezoneShortName': 'EST',
#   'fiftyDayAverage': 147.205,
#   'fiftyDayAverageChange': 3.9051056,
#   'fiftyDayAverageChangePercent': 0.02652835,
#   'fiftyTwoWeekHigh': 182.94,
#   'fiftyTwoWeekHighChange': -31.829895,
#   'fiftyTwoWeekHighChangePercent': -0.17399089,
#   'fiftyTwoWeekLow': 129.04,
#   'fiftyTwoWeekLowChange': 22.070114,
#   'fiftyTwoWeekLowChangePercent': 0.17103313,
#   'financialCurrency': 'USD',
#   'forwardPE': 22.156906,
#   'fullExchangeName': 'NasdaqGS',
#   'gmtOffSetMilliseconds': -18000000,
#   'language': 'en-US',
#   'longName': 'Apple Inc.',
#   'market': 'us_market',
#   'marketCap': 2403874635776,
#   'marketState': 'REGULAR',
#   'messageBoardId': 'finmb_24937',
#   'postMarketChange': None,
#   'postMarketChangePercent': None,
#   'postMarketPrice': None,
#   'postMarketTime': None,
#   'priceHint': 2,
#   'priceToBook': 47.548805,
#   'quoteSourceName': 'Nasdaq Real Time Price',
#   'quoteType': 'EQUITY',
#   'regularMarketChange': 0.3901062,
#   'regularMarketChangePercent': 0.25882843,
#   'regularMarketDayHigh': 152.57,
#   'regularMarketDayLow': 149.97,
#   'regularMarketOpen': 152.305,
#   'regularMarketPreviousClose': 150.72,
#   'regularMarketPrice': 151.1101,
#   'regularMarketTime': {'date': '2022-11-18 19:05:49.000000',
#                         'timezone': '+00:00',
#                         'timezone_type': 1},
#   'regularMarketVolume': 44167107,
#   'sharesOutstanding': 15908100096,
#   'shortName': 'Apple Inc.',
#   'sourceInterval': 15,
#   'symbol': 'AAPL',
#   'tradeable': False,
#   'trailingAnnualDividendRate': 0.9,
#   'trailingAnnualDividendYield': 0.005971337,
#   'trailingPE': 24.731606,
#   'twoHundredDayAverage': 155.19215,
#   'twoHundredDayAverageChange': -4.0820465,
#   'twoHundredDayAverageChangePercent': -0.026303176}]

# %%
def get_stock_info():
  url = "https://yahoo-finance97.p.rapidapi.com/stock-info"

  payload = "symbol=AAPL"
  headers = {
    "content-type": "application/x-www-form-urlencoded",
    "X-RapidAPI-Key": "YOUR API KEY",
    "X-RapidAPI-Host": "yahoo-finance97.p.rapidapi.com"
  }

  response = requests.request("POST", url, data=payload, headers=headers)
  data = json.loads(response.text)

  return (data, response.status_code)

def get_earnings():
  url = "https://yahoo-finance97.p.rapidapi.com/earnings"

  payload = "symbol=AAPL"
  headers = {
    "content-type": "application/x-www-form-urlencoded",
    "X-RapidAPI-Key": "YOUR API KEY",
    "X-RapidAPI-Host": "yahoo-finance97.p.rapidapi.com"
  }

  response = requests.request("POST", url, data=payload, headers=headers)
  data = json.loads(response.text)

  return (data, response.status_code)

def get_financials():
  url = "https://yahoo-finance97.p.rapidapi.com/financials"

  payload = "symbol=AAPL"
  headers = {
    "content-type": "application/x-www-form-urlencoded",
    "X-RapidAPI-Key": "YOUR API KEY",
    "X-RapidAPI-Host": "yahoo-finance97.p.rapidapi.com"
  }

  response = requests.request("POST", url, data=payload, headers=headers)
  data = json.loads(response.text)

  return (data, response.status_code)

def get_calendar():
  url = "https://yahoo-finance97.p.rapidapi.com/calendar"

  payload = "symbol=AAPL"
  headers = {
    "content-type": "application/x-www-form-urlencoded",
    "X-RapidAPI-Key": "YOUR API KEY",
    "X-RapidAPI-Host": "yahoo-finance97.p.rapidapi.com"
  }

  response = requests.request("POST", url, data=payload, headers=headers)
  data = json.loads(response.text)

  return (data, response.status_code)

def get_quarterly_earnings():
  url = "https://yahoo-finance97.p.rapidapi.com/quarterly-earnings"

  payload = "symbol=AAPL"
  headers = {
    "content-type": "application/x-www-form-urlencoded",
    "X-RapidAPI-Key": "YOUR API KEY",
    "X-RapidAPI-Host": "yahoo-finance97.p.rapidapi.com"
  }

  response = requests.request("POST", url, data=payload, headers=headers)
  data = json.loads(response.text)

  return (data, response.status_code)
