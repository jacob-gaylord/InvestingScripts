# %%
import sqlalchemy as sa
import yfinance as yf
import pandas as pd
import PyPDF2 as pdf
import tabula
import pyodbc

# %%
file = open("C:\\Users\\Personal\\Downloads\\smid_by_sector.pdf", 'rb')
fileReader = pdf.PdfFileReader(file)
n_pages = fileReader.numPages
table = tabula.read_pdf("C:\\Users\\Personal\\Downloads\\smid_by_sector.pdf", pages = 'all')
tickers = []
for i in range(3):
    tickers.append(table[i]['Unnamed: 1'])

tickers = pd.concat(tickers)
tickers.dropna(inplace = True)
tickers = tickers[tickers != 'Symbol']
tickers = tickers[tickers != 'n/a']
tickers.reset_index(drop = True, inplace = True)
tickers = tickers.drop_duplicates()
tickers = tickers[:-1]

tickers = tickers.to_list()
tickers
# Out:
# ['LBTYA',
#  'WBD',
#  'BURL',
#  'CHWY',
#  'MGM',
#  'MTN',
#  'BRBR',
#  'LW',
#  'POST',
#  'BRO',
#  'FFIN',
#  'MKL',
#  'MTB',
#  'RLI',
#  'SIVB',
#  'WRB',
#  'CHE',
#  'WST',
#  'DCI',
#  'GXO',
#  'RBC',
#  'WCN',
#  'GWRE',
#  'KEYS',
#  'TYL',
#  'AXTA',
#  'RPM',
#  'ADC',
#  'DEI',
#  'FSV',
#  'STAG',
#  'SUI',
#  'BEPC']

# %%
df = pd.DataFrame()

# %%
for ticker in tickers:
    var = yf.Ticker(ticker).info
    frame = pd.DataFrame([var])
    df = df.append(frame)
# Out:
# C:\Users\Personal\AppData\Local\Temp\ipykernel_9844\1765096808.py:4: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(frame)
# C:\Users\Personal\AppData\Local\Temp\ipykernel_9844\1765096808.py:4: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(frame)
# C:\Users\Personal\AppData\Local\Temp\ipykernel_9844\1765096808.py:4: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(frame)
# C:\Users\Personal\AppData\Local\Temp\ipykernel_9844\1765096808.py:4: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(frame)
# C:\Users\Personal\AppData\Local\Temp\ipykernel_9844\1765096808.py:4: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(frame)
# C:\Users\Personal\AppData\Local\Temp\ipykernel_9844\1765096808.py:4: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(frame)
# C:\Users\Personal\AppData\Local\Temp\ipykernel_9844\1765096808.py:4: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(frame)
# C:\Users\Personal\AppData\Local\Temp\ipykernel_9844\1765096808.py:4: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(frame)
# C:\Users\Personal\AppData\Local\Temp\ipykernel_9844\1765096808.py:4: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(frame)
# C:\Users\Personal\AppData\Local\Temp\ipykernel_9844\1765096808.py:4: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(frame)
# C:\Users\Personal\AppData\Local\Temp\ipykernel_9844\1765096808.py:4: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(frame)
# C:\Users\Personal\AppData\Local\Temp\ipykernel_9844\1765096808.py:4: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(frame)
# C:\Users\Personal\AppData\Local\Temp\ipykernel_9844\1765096808.py:4: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(frame)
# C:\Users\Personal\AppData\Local\Temp\ipykernel_9844\1765096808.py:4: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(frame)
# C:\Users\Personal\AppData\Local\Temp\ipykernel_9844\1765096808.py:4: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(frame)
# C:\Users\Personal\AppData\Local\Temp\ipykernel_9844\1765096808.py:4: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(frame)
# C:\Users\Personal\AppData\Local\Temp\ipykernel_9844\1765096808.py:4: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(frame)
# C:\Users\Personal\AppData\Local\Temp\ipykernel_9844\1765096808.py:4: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(frame)
# C:\Users\Personal\AppData\Local\Temp\ipykernel_9844\1765096808.py:4: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(frame)
# C:\Users\Personal\AppData\Local\Temp\ipykernel_9844\1765096808.py:4: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(frame)
# C:\Users\Personal\AppData\Local\Temp\ipykernel_9844\1765096808.py:4: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(frame)
# C:\Users\Personal\AppData\Local\Temp\ipykernel_9844\1765096808.py:4: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(frame)
# C:\Users\Personal\AppData\Local\Temp\ipykernel_9844\1765096808.py:4: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(frame)
# C:\Users\Personal\AppData\Local\Temp\ipykernel_9844\1765096808.py:4: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(frame)
# C:\Users\Personal\AppData\Local\Temp\ipykernel_9844\1765096808.py:4: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(frame)
# C:\Users\Personal\AppData\Local\Temp\ipykernel_9844\1765096808.py:4: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(frame)

# %%
engine = sa.create_engine('mssql+pyodbc://sqluser:password@DevSQLServer')

# %%
subdf = df[['symbol', 'dividendYield', 'sector', 'shortRatio', 'forwardPE', 'trailingPE']]

# %%
subdf.to_sql('Fundamentals', engine, index = False)
# Out:
# -1

# %%
pd.read_sql('Fundamentals', engine)
# Out:
#    symbol  dividendYield                  sector  shortRatio    forwardPE  \
# 0   LBTYA            NaN  Communication Services        2.85   -42.922226
# 1     WBD            NaN  Communication Services        4.42  -358.666700
# 2    BURL            NaN       Consumer Cyclical        3.42    25.968853
# 3    CHWY            NaN       Consumer Cyclical        5.87  1349.666700
# 4     MGM         0.0003       Consumer Cyclical        3.34    39.150536
# 5     MTN         0.0321       Consumer Cyclical        1.85    23.912893
# 6    BRBR            NaN      Consumer Defensive        9.26    17.903227
# 7      LW         0.0118      Consumer Defensive        1.32    21.288607
# 8    POST            NaN      Consumer Defensive        5.67    31.097904
# 9     BRO         0.0082      Financial Services        1.84    22.899600
# 10   FFIN         0.0181      Financial Services       15.16    21.462210
# 11    MKL            NaN      Financial Services        2.06    15.341607
# 12    MTB         0.0285      Financial Services        1.97     8.767081
# 13    RLI         0.0080      Financial Services        6.64    28.742794
# 14   SIVB            NaN      Financial Services        2.03     9.917296
# 15    WRB         0.0056      Financial Services        1.54    14.639676
# 16    CHE         0.0031              Healthcare        3.64    24.792679
# 17    WST         0.0034              Healthcare        1.03    30.395920
# 18    DCI         0.0153             Industrials        3.30    18.829113
# 19    GXO            NaN             Industrials        3.90    15.859847
# 20    RBC            NaN             Industrials       10.49    28.444971
# 21    WCN         0.0074             Industrials        2.50    32.949295
# 22   GWRE            NaN              Technology        6.61   409.285700
# 23   KEYS            NaN              Technology        3.38    21.452950
# 24    TYL            NaN              Technology        1.91    40.428574
# 25   AXTA            NaN         Basic Materials        2.28    14.566384
# 26    RPM         0.0170         Basic Materials        3.12    19.294004
# 27    ADC         0.0417             Real Estate        6.89    42.284847
# 28    DEI         0.0680             Real Estate        3.54    28.705263
# 29    FSV         0.0065             Real Estate       10.11    26.343948
# 30   STAG         0.0453             Real Estate        2.67    49.280304
# 31    SUI         0.0253             Real Estate        2.22    45.646780
# 32   BEPC         0.0409               Utilities        3.03   105.586210
#
#     trailingPE
# 0     1.686900
# 1     5.944752
# 2    64.394310
# 3          NaN
# 4    12.016501
# 5    28.482416
# 6    25.813953
# 7    30.248201
# 8     7.442678
# 9    25.800905
# 10   22.787037
# 11  693.254200
# 12   16.116080
# 13   10.215131
# 14    8.781102
# 15   15.619870
# 16   29.284628
# 17   27.080000
# 18   22.368420
# 19   25.375757
# 20   70.280700
# 21   44.634186
# 22         NaN
# 23   29.127768
# 24   74.262410
# 25   29.298294
# 26   24.568966
# 27   38.125680
# 28   32.082350
# 29   48.468750
# 30   24.272388
# 31   68.691750
# 32    7.973959
